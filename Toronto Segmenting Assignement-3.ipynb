# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Web Scraping using pandas read_html method

# %%
data = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M",header=0,attrs={"class": ["wikitable","wikitable sortable"]})

for row in data:
    df = pd.DataFrame(row)
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ## Droping Borough column which contains Not assigned data

# %%
df_new = df.drop(df[df.Borough == 'Not assigned'].index,axis=0)

# %%
df_new.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %% [markdown]
# ## Replacing 8th row Neighbourhood column with Queen's Park

# %%
df_new.loc[8]['Neighbourhood'] = "Queen's Park"

# %%
df_new.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Queen's Park
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %% [markdown]
# ## Shape of Dataframe

# %%
df_new.shape
# Out:
# (211, 3)

# %% [markdown]
# ## Rename Postcode to Postal Code

# %%
df_new.rename(index=str, columns={"Postcode": "Postal Code"},inplace=True)
df_new.head(10)
# Out:
#    Postal Code           Borough     Neighbourhood
# 2          M3A        North York         Parkwoods
# 3          M4A        North York  Victoria Village
# 4          M5A  Downtown Toronto      Harbourfront
# 5          M5A  Downtown Toronto       Regent Park
# 6          M6A        North York  Lawrence Heights
# 7          M6A        North York    Lawrence Manor
# 8          M7A      Queen's Park      Queen's Park
# 10         M9A         Etobicoke  Islington Avenue
# 11         M1B       Scarborough             Rouge
# 12         M1B       Scarborough           Malvern

# %% [markdown]
# ## Loading Lat Longs from http://cocl.us/Geospatial_data

# %%
dframe = pd.read_csv('http://cocl.us/Geospatial_data')
dframe.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## Joining two Dataframes

# %%
df_new.set_index('Postal Code',inplace=True)
dframe.set_index('Postal Code',inplace=True)

# %%
df_mod = pd.concat([df_new, dframe], axis=1, join='inner')
df_mod.head(100)
# Out:
#                       Borough             Neighbourhood   Latitude  Longitude
# Postal Code
# M3A                North York                 Parkwoods  43.753259 -79.329656
# M4A                North York          Victoria Village  43.725882 -79.315572
# M5A          Downtown Toronto              Harbourfront  43.654260 -79.360636
# M5A          Downtown Toronto               Regent Park  43.654260 -79.360636
# M6A                North York          Lawrence Heights  43.718518 -79.464763
# M6A                North York            Lawrence Manor  43.718518 -79.464763
# M7A              Queen's Park              Queen's Park  43.662301 -79.389494
# M9A                 Etobicoke          Islington Avenue  43.667856 -79.532242
# M1B               Scarborough                     Rouge  43.806686 -79.194353
# M1B               Scarborough                   Malvern  43.806686 -79.194353
# M3B                North York           Don Mills North  43.745906 -79.352188
# M4B                 East York          Woodbine Gardens  43.706397 -79.309937
# M5J          Downtown Toronto             Union Station  43.640816 -79.381752
# M6J              West Toronto           Little Portugal  43.647927 -79.419750
# M6J              West Toronto                   Trinity  43.647927 -79.419750
# M1K               Scarborough      East Birchmount Park  43.727929 -79.262029
# M1K               Scarborough                   Ionview  43.727929 -79.262029
# M1K               Scarborough              Kennedy Park  43.727929 -79.262029
# M2K                North York           Bayview Village  43.786947 -79.385975
# M3K                North York               CFB Toronto  43.737473 -79.464763
# M3K                North York            Downsview East  43.737473 -79.464763
# M4K              East Toronto         The Danforth West  43.679557 -79.352188
# M4K              East Toronto                 Riverdale  43.679557 -79.352188
# M5K          Downtown Toronto           Design Exchange  43.647177 -79.381576
# M5K          Downtown Toronto   Toronto Dominion Centre  43.647177 -79.381576
# M6K              West Toronto                  Brockton  43.636847 -79.428191
# M6K              West Toronto          Exhibition Place  43.636847 -79.428191
# M6K              West Toronto          Parkdale Village  43.636847 -79.428191
# M1L               Scarborough                  Clairlea  43.711112 -79.284577
# M1L               Scarborough               Golden Mile  43.711112 -79.284577
# M1L               Scarborough                  Oakridge  43.711112 -79.284577
# M2L                North York              Silver Hills  43.757490 -79.374714
# M2L                North York                York Mills  43.757490 -79.374714
# M3L                North York            Downsview West  43.739015 -79.506944
# M4L              East Toronto          The Beaches West  43.668999 -79.315572
# M4L              East Toronto              India Bazaar  43.668999 -79.315572
# M5L          Downtown Toronto            Commerce Court  43.648198 -79.379817
# M5L          Downtown Toronto            Victoria Hotel  43.648198 -79.379817
# M6L                North York                 Downsview  43.713756 -79.490074
# M6L                North York                North Park  43.713756 -79.490074
# M6L                North York               Upwood Park  43.713756 -79.490074
# M9L                North York             Humber Summit  43.756303 -79.565963
# M1M               Scarborough                Cliffcrest  43.716316 -79.239476
# M1M               Scarborough                 Cliffside  43.716316 -79.239476
# M1M               Scarborough  Scarborough Village West  43.716316 -79.239476
# M2M                North York               Newtonbrook  43.789053 -79.408493
# M2M                North York                Willowdale  43.789053 -79.408493
# M3M                North York         Downsview Central  43.728496 -79.495697
# M4M              East Toronto           Studio District  43.659526 -79.340923

# %% [markdown]
# ## Selecting Downtown Toronto

# %%
dntoronto_data = df_mod[df_mod['Borough'] == 'Downtown Toronto']
dntoronto_data.head()
# Out:
#                       Borough    Neighbourhood   Latitude  Longitude
# Postal Code
# M5A          Downtown Toronto     Harbourfront  43.654260 -79.360636
# M5A          Downtown Toronto      Regent Park  43.654260 -79.360636
# M5B          Downtown Toronto          Ryerson  43.657162 -79.378937
# M5B          Downtown Toronto  Garden District  43.657162 -79.378937
# M5C          Downtown Toronto   St. James Town  43.651494 -79.375418

# %% [markdown]
# ## Use geopy library to get the latitude and longitude values of Downtown Toronto

# %%
address = 'Downtown Toronto, TO'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.65145205, -79.3620078930752.

# %%
# create map of downtown Toronto using latitude and longitude values
map_dntoronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(dntoronto_data['Latitude'], dntoronto_data['Longitude'], dntoronto_data['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dntoronto)  
    
map_dntoronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
